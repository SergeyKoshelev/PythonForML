# %%
import numpy as np

a = np.array([[3, 3, 3], [1, 3, 4], [7, 1, 3]])
np.unique(a)
# Out:
# array([1, 3, 4, 7])

# %%
z = np.array([92, 13, 44, 555, 1, -3])
z[::-1][4]
# Out:
# 13

# %%
b = np.full(shape = (5), fill_value = 1)
c = b * 2
np.dot(c, b)
# Out:
# 10

# %%
d = np.array([[0, 9, 19, 13], [1, 20, 5, 13], [12, 11, 3, 4]])
e = np.array([[2, 0, 0 , 0], [1, 2, 2, 0], [2, 1, 1, 0], [0, 0, 1, 1]])
np.dot(d, e)
# Out:
# array([[47, 37, 50, 13],
#        [32, 45, 58, 13],
#        [41, 25, 29,  4]])

# %%
f = np.array([[-1, 33, 4, 1], [0, 1, 1, 0]])
f.mean()
# Out:
# 4.875

# %%
from scipy import linalg

g = np.array([[6, 0, 3], [0, -1, 2], [12, 3, 0]])
linalg.det(g)
# Out:
# 0.0

# %%
h = np.array([[1, -1, -1, 0], [-1, 2, -1, -1], [-1, -1, 2, -1], [0, -1, -1, 1]])
values, vectors = linalg.eig(h)
values
# Out:
# array([-1.+0.j,  1.+0.j,  3.+0.j,  3.+0.j])

# %%
#i = np.array([[2, 4, 0, 4, 1],
             [2, 4, 1, 1, 0],
             [1, 1, 1, 2, 2],
             [0, 1, 3, 2, 4],
             [2, 2, 2, 0, 2]])
#np.trace(linalg.inv(i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-02c1772d5267> in <module>
# ----> 1 i = np.array([[2, 4, 0, 4, 1],
#       2              [2, 4, 1, 1, 0],
#       3              [1, 1, 1, 2, 2],
#       4              [0, 1, 3, 2, 4],
#       5              [2, 2, 2, 0, 2]])
#
# NameError: name 'np' is not defined

# %%
import numpy as np

np.math.factorial(10)*1024/np.math.factorial(20)
# Out:
# 1.5273493085670588e-09
